# %%
from tensorflow import keras
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Conv2D
from keras.layers import MaxPooling2D
from keras.layers import Flatten
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
model = Sequential()
model.add(Conv2D(32,3, 3, input_shape=(64,64, 3),activation ='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Conv2D(34,5, 5,activation ='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Flatten())
model.add(Dense(units=128, activation='relu'))
model.add(Dense(units=1, activation='sigmoid'))

# %%
from tensorflow import keras
model=keras.models.Sequential([
    keras.layers.Conv2D(filters=128, kernel_size=(11,11), strides=(4,4), activation='relu', input_shape=(64,64,3)),
    keras.layers.BatchNormalization(),
    keras.layers.MaxPool2D(pool_size=(2,2)),
    keras.layers.Conv2D(filters=256, kernel_size=(5,5), strides=(1,1), activation='relu', padding="same"),
    keras.layers.BatchNormalization(),
    keras.layers.MaxPool2D(pool_size=(3,3)),
    keras.layers.Conv2D(filters=256, kernel_size=(3,3), strides=(1,1), activation='relu', padding="same"),
    keras.layers.BatchNormalization(),
    keras.layers.Conv2D(filters=256, kernel_size=(1,1), strides=(1,1), activation='relu', padding="same"),
    keras.layers.BatchNormalization(),
    keras.layers.Conv2D(filters=256, kernel_size=(1,1), strides=(1,1), activation='relu', padding="same"),
    keras.layers.BatchNormalization(),
    keras.layers.MaxPool2D(pool_size=(2,2)),
    keras.layers.Flatten(),
    keras.layers.Dense(1024,activation='relu'),
    #keras.layers.Dropout(0.5),
    keras.layers.Dense(1024,activation='relu'),
    #keras.layers.Dropout(0.5),
    keras.layers.Dense(1,activation='sigmoid')


])

# %%
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
train_datagen = ImageDataGenerator(rescale=1./255, shear_range=0.2, zoom_range=0.2, horizontal_flip=True)
test_datagen = ImageDataGenerator(rescale=1./255)

# %%
training_set= train_datagen.flow_from_directory('/content/drive/MyDrive/train',target_size=(64,64),batch_size=8, class_mode='binary')
test_set = test_datagen.flow_from_directory('/content/drive/MyDrive/test',target_size=(64,64),batch_size=8, class_mode='binary')
# Out:
# Found 2002 images belonging to 2 classes.
# Found 620 images belonging to 2 classes.

# %%
adam_history= model.fit(training_set,steps_per_epoch=30,epochs=100)
# Out:
# Epoch 1/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 11s 323ms/step - accuracy: 0.9450 - loss: 0.1159
# Epoch 2/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 6s 205ms/step - accuracy: 0.9787 - loss: 0.0756
# Epoch 3/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 8s 269ms/step - accuracy: 0.9628 - loss: 0.0760
# Epoch 4/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 6s 210ms/step - accuracy: 0.9519 - loss: 0.1448
# Epoch 5/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 8s 271ms/step - accuracy: 0.9758 - loss: 0.0649
# Epoch 6/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 7s 220ms/step - accuracy: 0.9599 - loss: 0.0968
# Epoch 7/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 8s 254ms/step - accuracy: 0.9461 - loss: 0.1112
# Epoch 8/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 8s 255ms/step - accuracy: 0.9528 - loss: 0.1301
# Epoch 9/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - accuracy: 0.9389 - loss: 0.1410
# Epoch 10/100
# ...

# %%
test_loss,test_acc=model.evaluate(test_set,verbose=2)
print("\n")
print("test_loss:",test_loss,"\n")
print("test_accuracy:",test_acc,"\n")
# Out:
# 78/78 - 11s - 138ms/step - accuracy: 0.9306 - loss: 0.1855
#
#
# test_loss: 0.18551687896251678
#
# test_accuracy: 0.9306451678276062

# %%
import matplotlib.pyplot as plt
plt.plot(adam_history.history['accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['Accuracy'], loc='upper left')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
model.compile(optimizer='adagrad', loss='binary_crossentropy', metrics=['accuracy'])

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
train_datagen = ImageDataGenerator(rescale=1./255, shear_range=0.2, zoom_range=0.2, horizontal_flip=True)
test_datagen = ImageDataGenerator(rescale=1./255)

# %%
adagrad_history=model.fit(training_set,steps_per_epoch=30,epochs=100)
# Out:
# Epoch 1/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 7s 208ms/step - accuracy: 0.9679 - loss: 0.0822
# Epoch 2/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 8s 277ms/step - accuracy: 0.9620 - loss: 0.1196
# Epoch 3/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 7s 228ms/step - accuracy: 0.9710 - loss: 0.0888
# Epoch 4/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 12s 409ms/step - accuracy: 0.9787 - loss: 0.0626
# Epoch 5/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 10s 330ms/step - accuracy: 0.9619 - loss: 0.0571
# Epoch 6/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 8s 247ms/step - accuracy: 0.9774 - loss: 0.0593
# Epoch 7/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 8s 276ms/step - accuracy: 0.9678 - loss: 0.0954
# Epoch 8/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 7s 230ms/step - accuracy: 0.9684 - loss: 0.0730
# Epoch 9/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 54ms/step - accuracy: 0.9496 - loss: 0.1370
# Epoch 10/100
# ...

# %%
test_loss,test_acc=model.evaluate(test_set,verbose=2)
print("\n")
print("test_loss:",test_loss,"\n")
print("test_accuracy:",test_acc,"\n")
# Out:
# 78/78 - 10s - 134ms/step - accuracy: 0.9242 - loss: 0.1992
#
#
# test_loss: 0.19917869567871094
#
# test_accuracy: 0.9241935610771179

# %%
import matplotlib.pyplot as plt
plt.plot(adagrad_history.history['accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['Accuracy'], loc='upper left')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
model.compile(optimizer='adadelta', loss='binary_crossentropy', metrics=['accuracy'])

# %%
adadelta_history=model.fit(training_set,steps_per_epoch=30,epochs=100)
# Out:
# Epoch 1/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 14s 242ms/step - accuracy: 0.9714 - loss: 0.1169
# Epoch 2/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 9s 310ms/step - accuracy: 0.9809 - loss: 0.0822
# Epoch 3/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 7s 229ms/step - accuracy: 0.9532 - loss: 0.1412
# Epoch 4/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 9s 302ms/step - accuracy: 0.9489 - loss: 0.1284
# Epoch 5/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 7s 235ms/step - accuracy: 0.9592 - loss: 0.1481
# Epoch 6/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 9s 297ms/step - accuracy: 0.9778 - loss: 0.0620
# Epoch 7/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 7s 238ms/step - accuracy: 0.9868 - loss: 0.0520
# Epoch 8/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 9s 287ms/step - accuracy: 0.9803 - loss: 0.0695
# Epoch 9/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - accuracy: 0.9773 - loss: 0.0840
# Epoch 10/100
# ...

# %%
test_loss,test_acc=model.evaluate(test_set,verbose=2)
print("\n")
print("test_loss:",test_loss,"\n")
print("test_accuracy:",test_acc,"\n")
# Out:
# 78/78 - 10s - 133ms/step - accuracy: 0.9258 - loss: 0.1994
#
#
# test_loss: 0.19944536685943604
#
# test_accuracy: 0.92580646276474

# %%
import matplotlib.pyplot as plt
plt.plot(adadelta_history.history['accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['Accuracy'], loc='upper left')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
model.compile(optimizer='RMSprop', loss='binary_crossentropy', metrics=['accuracy'])

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
train_datagen = ImageDataGenerator(rescale=1./255, shear_range=0.2, zoom_range=0.2, horizontal_flip=True)
test_datagen = ImageDataGenerator(rescale=1./255)

# %%
RMSprop_history=model.fit(training_set,steps_per_epoch=30,epochs=100)
# Out:
# Epoch 1/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 11s 224ms/step - accuracy: 0.9631 - loss: 0.1312
# Epoch 2/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 9s 288ms/step - accuracy: 0.9237 - loss: 0.3124
# Epoch 3/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 6s 212ms/step - accuracy: 0.9407 - loss: 0.1275
# Epoch 4/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 9s 292ms/step - accuracy: 0.9723 - loss: 0.1490
# Epoch 5/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 7s 227ms/step - accuracy: 0.9380 - loss: 0.1314
# Epoch 6/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 9s 291ms/step - accuracy: 0.9274 - loss: 0.1779
# Epoch 7/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 7s 221ms/step - accuracy: 0.9318 - loss: 0.2026
# Epoch 8/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 9s 289ms/step - accuracy: 0.9694 - loss: 0.0671
# Epoch 9/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - accuracy: 0.9910 - loss: 0.0900
# Epoch 10/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 28s 282ms/step - accuracy: 0.9729 - loss: 0.0844
# Epoch 11/100
# ...

# %%
test_loss,test_acc=model.evaluate(test_set,verbose=2)
print("\n")
print("test_loss:",test_loss,"\n")
print("test_accuracy:",test_acc,"\n")
# Out:
# 78/78 - 11s - 145ms/step - accuracy: 0.9210 - loss: 0.2129
#
#
# test_loss: 0.21291907131671906
#
# test_accuracy: 0.9209677577018738

# %%
import matplotlib.pyplot as plt
plt.plot(RMSprop_history.history['accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['Accuracy'], loc='upper left')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
model.compile(optimizer='SGD', loss='binary_crossentropy', metrics=['accuracy'])

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
train_datagen = ImageDataGenerator(rescale=1./255, shear_range=0.2, zoom_range=0.2, horizontal_flip=True)
test_datagen = ImageDataGenerator(rescale=1./255)

# %%
SGD_history=model.fit(training_set,steps_per_epoch=30,epochs=100)
# Out:
# Epoch 1/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 9s 210ms/step - accuracy: 0.9340 - loss: 0.1971
# Epoch 2/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 8s 279ms/step - accuracy: 0.9572 - loss: 0.1033
# Epoch 3/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 6s 217ms/step - accuracy: 0.9585 - loss: 0.2774
# Epoch 4/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 8s 274ms/step - accuracy: 0.9777 - loss: 0.0581
# Epoch 5/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 6s 213ms/step - accuracy: 0.9577 - loss: 0.1120
# Epoch 6/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 8s 278ms/step - accuracy: 0.9723 - loss: 0.0703
# Epoch 7/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 7s 220ms/step - accuracy: 0.9629 - loss: 0.0995
# Epoch 8/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 8s 281ms/step - accuracy: 0.9525 - loss: 0.1010
# Epoch 9/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - accuracy: 0.9657 - loss: 0.1153
# Epoch 10/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 7s 215ms/step - accuracy: 0.9581 - loss: 0.0925
# Epoch 11/100
# ...

# %%
test_loss,test_acc=model.evaluate(test_set,verbose=2)
print("\n")
print("test_loss:",test_loss,"\n")
print("test_accuracy:",test_acc,"\n")
# Out:
# 78/78 - 10s - 128ms/step - accuracy: 0.9355 - loss: 0.1759
#
#
# test_loss: 0.17589126527309418
#
# test_accuracy: 0.9354838728904724

# %%
import matplotlib.pyplot as plt
plt.plot(SGD_history.history['accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['Accuracy'], loc='upper left')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#Dropout
from tensorflow import keras
model=keras.models.Sequential([
    keras.layers.Conv2D(filters=128, kernel_size=(11,11), strides=(4,4), activation='relu', input_shape=(64,64,3)),
    keras.layers.BatchNormalization(),
    keras.layers.MaxPool2D(pool_size=(2,2)),
    keras.layers.Conv2D(filters=256, kernel_size=(5,5), strides=(1,1), activation='relu', padding="same"),
    keras.layers.BatchNormalization(),
    keras.layers.MaxPool2D(pool_size=(3,3)),
    keras.layers.Conv2D(filters=256, kernel_size=(3,3), strides=(1,1), activation='relu', padding="same"),
    keras.layers.BatchNormalization(),
    keras.layers.Conv2D(filters=256, kernel_size=(1,1), strides=(1,1), activation='relu', padding="same"),
    keras.layers.BatchNormalization(),
    keras.layers.Conv2D(filters=256, kernel_size=(1,1), strides=(1,1), activation='relu', padding="same"),
    keras.layers.BatchNormalization(),
    keras.layers.MaxPool2D(pool_size=(2,2)),
    keras.layers.Flatten(),
    keras.layers.Dense(1024,activation='relu'),
    keras.layers.Dropout(0.5),
    keras.layers.Dense(1024,activation='relu'),
    keras.layers.Dropout(0.5),
    keras.layers.Dense(1,activation='sigmoid')


])
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
train_datagen = ImageDataGenerator(rescale=1./255, shear_range=0.2, zoom_range=0.2, horizontal_flip=True)
test_datagen = ImageDataGenerator(rescale=1./255)

# %%
adam1_history=model.fit(training_set,steps_per_epoch=30,epochs=100)
# Out:
# Epoch 1/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 73s 288ms/step - accuracy: 0.6637 - loss: 0.8485
# Epoch 2/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 7s 239ms/step - accuracy: 0.6897 - loss: 1.1604
# Epoch 3/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 8s 274ms/step - accuracy: 0.7899 - loss: 0.7194
# Epoch 4/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 7s 235ms/step - accuracy: 0.8741 - loss: 0.6287
# Epoch 5/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 9s 278ms/step - accuracy: 0.7786 - loss: 0.7183
# Epoch 6/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 7s 230ms/step - accuracy: 0.8385 - loss: 0.3552
# Epoch 7/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 9s 290ms/step - accuracy: 0.8321 - loss: 0.4822
# Epoch 8/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 7s 224ms/step - accuracy: 0.8591 - loss: 0.3598
# Epoch 9/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 73ms/step - accuracy: 0.8029 - loss: 0.5595
# Epoch 10/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 8s 218ms/step - accuracy: 0.8520 - loss: 0.4270
# Epoch 11/100
# ...

# %%
test_loss,test_acc=model.evaluate(test_set,verbose=2)
print("\n")
print("test_loss:",test_loss,"\n")
print("test_accuracy:",test_acc,"\n")
# Out:
# 78/78 - 11s - 139ms/step - accuracy: 0.7565 - loss: 0.6707
#
#
# test_loss: 0.6706743240356445
#
# test_accuracy: 0.7564516067504883

# %%
import matplotlib.pyplot as plt
plt.plot(adam1_history.history['accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['Accuracy'], loc='upper left')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# Transfer Learning Resnet Model
import tensorflow as tf
resnet_model = Sequential()

pretrained_model= tf.keras.applications.ResNet50(include_top=False,
                   input_shape=(64,64,3),
                   pooling='avg',classes=2,
                   weights='imagenet')
for layer in pretrained_model.layers:
        layer.trainable=False

resnet_model.add(pretrained_model)
resnet_model.add(Flatten())
resnet_model.add(Dense(512, activation='relu'))
resnet_model.add(Dense(1, activation='sigmoid'))

resnet_model.compile(optimizer='adadelta',loss='binary_crossentropy',metrics=['accuracy'])
rnet_history=resnet_model.fit(training_set, steps_per_epoch=30,epochs=100)
# Out:
# ...
# 94765736/94765736 ━━━━━━━━━━━━━━━━━━━━ 1s 0us/step
# Epoch 1/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 19s 270ms/step - accuracy: 0.5128 - loss: 0.6993
# Epoch 2/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 9s 294ms/step - accuracy: 0.5270 - loss: 0.6957
# Epoch 3/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 9s 294ms/step - accuracy: 0.4669 - loss: 0.7122
# Epoch 4/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 8s 272ms/step - accuracy: 0.4504 - loss: 0.7150
# Epoch 5/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 10s 328ms/step - accuracy: 0.4918 - loss: 0.7011
# Epoch 6/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 7s 249ms/step - accuracy: 0.5434 - loss: 0.6892
# Epoch 7/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 10s 334ms/step - accuracy: 0.4891 - loss: 0.7009
# Epoch 8/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 8s 251ms/step - accuracy: 0.5441 - loss: 0.6875
# Epoch 9/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 92ms/step - accuracy: 0.5471 - loss: 0.6866
# Epoch 10/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 20s 333ms/step - accuracy: 0.5347 - loss: 0.6882
# Epoch 11/100
# ...

# %%
test_loss,test_acc=resnet_model.evaluate(test_set,verbose=2)
print("\n")
print("test_Loss: ",test_loss,"\n")
print("test_Accuracy: ",test_acc,"\n")
# Out:
# 78/78 - 20s - 259ms/step - accuracy: 0.7081 - loss: 0.6718
#
#
# test_Loss:  0.6717702746391296
#
# test_Accuracy:  0.7080644965171814

# %%
import matplotlib.pyplot as plt
plt.plot(rnet_history.history['accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['Accuracy'], loc='upper left')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#VGG 16
from tensorflow.keras.applications.vgg16 import VGG16
vgg_model = Sequential()
base_model = VGG16(weights="imagenet",include_top=False, input_shape=(64,64,3))
base_model.trainable = False
vgg_model.add(base_model)
vgg_model.add(Flatten())
vgg_model.add(Dense(512, activation="relu"))
vgg_model.add(Dense(1, activation="sigmoid"))

vgg_model.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])
vgg16_history=vgg_model.fit(training_set, steps_per_epoch=30,epochs=100)
# Out:
# ...
# 58889256/58889256 ━━━━━━━━━━━━━━━━━━━━ 1s 0us/step
# Epoch 1/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 20s 573ms/step - accuracy: 0.6827 - loss: 0.5521
# Epoch 2/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 16s 536ms/step - accuracy: 0.8715 - loss: 0.3348
# Epoch 3/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 17s 556ms/step - accuracy: 0.8833 - loss: 0.2143
# Epoch 4/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 17s 564ms/step - accuracy: 0.9343 - loss: 0.1643
# Epoch 5/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 18s 576ms/step - accuracy: 0.9074 - loss: 0.2415
# Epoch 6/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 17s 555ms/step - accuracy: 0.9166 - loss: 0.1977
# Epoch 7/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 17s 556ms/step - accuracy: 0.9208 - loss: 0.1865
# Epoch 8/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 16s 549ms/step - accuracy: 0.9371 - loss: 0.1667
# Epoch 9/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 4s 129ms/step - accuracy: 0.9347 - loss: 0.2333
# Epoch 10/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 18s 563ms/step - accuracy: 0.9551 - loss: 0.1596
# Epoch 11/100
# ...

# %%
test_loss,test_acc=vgg_model.evaluate(test_set,verbose=2)
print("\n")
print("test_Loss: ",test_loss,"\n")
print("test_Accuracy: ",test_acc,"\n")
# Out:
# 78/78 - 38s - 493ms/step - accuracy: 0.8871 - loss: 0.2979
#
#
# test_Loss:  0.2979313135147095
#
# test_Accuracy:  0.8870967626571655

# %%
import matplotlib.pyplot as plt
plt.plot(vgg16_history.history['accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['Accuracy'], loc='upper left')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#Vgg19
from tensorflow.keras.applications.vgg19 import VGG19
vgg_model1 = Sequential()
base_model1 = VGG19(weights="imagenet",include_top=False, input_shape=(64,64,3))
base_model1.trainable = False
vgg_model1.add(base_model1)
vgg_model1.add(Flatten())
vgg_model1.add(Dense(512, activation="relu"))
vgg_model1.add(Dense(1, activation="sigmoid"))

vgg_model1.compile(optimizer='adadelta',loss='binary_crossentropy',metrics=['accuracy'])
vgg19_history=vgg_model1.fit(training_set, steps_per_epoch=30,epochs=100)
# Out:
# ...
# 80134624/80134624 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Epoch 1/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 23s 670ms/step - accuracy: 0.5079 - loss: 0.6918
# Epoch 2/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 21s 702ms/step - accuracy: 0.6037 - loss: 0.6733
# Epoch 3/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 20s 660ms/step - accuracy: 0.6066 - loss: 0.6721
# Epoch 4/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 19s 651ms/step - accuracy: 0.5779 - loss: 0.6733
# Epoch 5/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 19s 651ms/step - accuracy: 0.6343 - loss: 0.6573
# Epoch 6/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 22s 723ms/step - accuracy: 0.7507 - loss: 0.6415
# Epoch 7/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 20s 654ms/step - accuracy: 0.6125 - loss: 0.6663
# Epoch 8/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 19s 645ms/step - accuracy: 0.8071 - loss: 0.6316
# Epoch 9/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 6s 202ms/step - accuracy: 0.6786 - loss: 0.6402
# Epoch 10/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 56s 705ms/step - accuracy: 0.7309 - loss: 0.6328
# Epoch 11/100
# ...

# %%
test_loss,test_acc=vgg_model1.evaluate(test_set,verbose=2)
print("\n")
print("test_Loss: ",test_loss,"\n")
print("test_Accuracy: ",test_acc,"\n")
# Out:
# 78/78 - 49s - 624ms/step - accuracy: 0.8000 - loss: 0.4741
#
#
# test_Loss:  0.47405868768692017
#
# test_Accuracy:  0.800000011920929

# %%
import matplotlib.pyplot as plt
plt.plot(vgg19_history.history['accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['Accuracy'], loc='upper left')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# Import necessary libraries
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.applications import Xception
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.xception import preprocess_input, decode_predictions
from skimage.segmentation import mark_boundaries

# %%
import numpy as np
from keras.preprocessing import image

# Ensure that 'test_image_path' points to a specific image file within the directory.
test_image_path = '/content/drive/MyDrive/test/NORMAL/NORMAL-1771524-0001.jpeg' # Example: replace 'your_image.jpg' with the actual image file name
test_image =image.load_img(test_image_path,target_size = (64, 64))
test_image = image.img_to_array(test_image)
test_image = np.expand_dims(test_image, axis = 0)
result = resnet_model.predict(test_image)
print(result)
training_set.class_indices
if result[0][0] > 0.5:
  result[0][0] = 1
else:
  result[0][0] = 0

if result[0][0] == 1:
  prediction = 'Normal'
else:
  prediction = 'Pneumonia'
print(prediction)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# [[0.23882921]]
# Pneumonia

# %%
# !pip install lime
import lime
from lime import lime_image
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 275.7/275.7 kB 8.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for lime: filename=lime-0.2.0.1-py3-none-any.whl size=283834 sha256=3945bed50473e022b8ed2641f45ee15ec63cc6eb79ac1ebd9ab4488342740807
#   Stored in directory: /root/.cache/pip/wheels/fd/a2/af/9ac0a1a85a27f314a06b39e1f492bee1547d52549a4606ed89
# Successfully built lime
# ...

# %%
# !pip install lime shap
#import lime
#import lime.lime_image
import shap
from skimage.segmentation import mark_boundaries
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 540.1/540.1 kB 9.0 MB/s eta 0:00:00
# ...

# %%
background = training_set

# Choose a sample index
sample_index = 0

explainer = lime_image.LimeImageExplainer()
image, label = background[sample_index]

# Select a single image from the batch if it's a batch of images
if image.ndim == 4:
  image = image[0]

# Ensure the input to explainer.explain_instance is a NumPy array
explanation = explainer.explain_instance(image.astype('double'),
                                         model.predict,
                                         hide_color=0,
                                         num_samples=1000)
# Out:
#   0%|          | 0/1000 [00:00<?, ?it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 290ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# ...

# %%
import matplotlib.pyplot as plt

# Access the image data from the DirectoryIterator
image_batch, labels = background[sample_index]

# Select a single image from the batch if it's a batch of images
if image_batch.ndim == 4:
  image = image_batch[0]
else:
  image = image_batch

# Display the image using plt.imshow
plt.imshow(image)
plt.title('Original Image')
plt.axis('off')
plt.show()

# %%
temp, mask = explanation.get_image_and_mask(explanation.top_labels[0], positive_only=True, num_features=5, hide_rest=False)
plt.imshow(mark_boundaries(temp, mask))
plt.title("LIME Explanation")
plt.show()

# %%
# !pip install shap
import shap

# %%
print(type(test_set))
tmp1, tmp2 = next(test_set)
background = shap.utils.sample(tmp1, 5)
explainer = shap.DeepExplainer(model, background)
# Out:
# <class 'keras.src.legacy.preprocessing.image.DirectoryIterator'>
# /usr/local/lib/python3.10/dist-packages/shap/explainers/_deep/deep_tf.py:99: UserWarning: Your TensorFlow version is newer than 2.4.0 and so graph support has been removed in eager mode and some static graphs may not be supported. See PR #1483 for discussion.
#   warnings.warn("Your TensorFlow version is newer than 2.4.0 and so graph support has been removed in eager mode and some static graphs may not be supported. See PR #1483 for discussion.")

# %%
sample_index = np.random.randint(0, background.shape[0])
sample_image = background[sample_index]

# %%
sample_image_batch = np.expand_dims(sample_image, axis=0)  # Add batch dimension
shap_values = explainer.shap_values(sample_image_batch)
sampled_images_array_scaled = sample_image_batch * 255
sampled_images_array_scaled = sampled_images_array_scaled.astype(np.uint8)

# %%
# Visualize the SHAP values
shap.image_plot(shap_values,sampled_images_array_scaled)
print(sampled_images_array_scaled.shape)
print(np.min(shap_values))
print(np.max(shap_values))
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# (1, 64, 64, 3)
# -1.032623003993649e-06
# 2.6353222892794292e-06

# %%
# Smoothgrad
NUM_ITERATIONS = 10 # equal to number of images that we wish to generate
shap_values_list = []
for _ in range(NUM_ITERATIONS):
    perturbed_image = sampled_images_array_scaled + np.random.normal(loc=0, scale=0.1, size=sampled_images_array_scaled.shape)
    perturbed_image = np.clip(perturbed_image, 0, 1)
    perturbed_image_batch = perturbed_image
    print("perturbed_image_batch: \n", perturbed_image_batch.shape, "\n")
    shap_values = explainer.shap_values(perturbed_image_batch)
    shap.image_plot(shap_values, perturbed_image_batch)
    shap_values_list.append(shap_values)

#print(shap_values_list[0])
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# perturbed_image_batch:
#  (1, 64, 64, 3)
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# perturbed_image_batch:
#  (1, 64, 64, 3)
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# perturbed_image_batch:
#  (1, 64, 64, 3)
# perturbed_image_batch:
#  (1, 64, 64, 3)
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# perturbed_image_batch:
#  (1, 64, 64, 3)
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# perturbed_image_batch:
#  (1, 64, 64, 3)
# ...

# %%
import tensorflow as tf
import numpy as np
import cv2
import matplotlib.pyplot as plt

# Function to generate Grad-CAM heatmap
def grad_cam(input_model, image, cls, layer_name):
    # Make sure the model is called on some data
    _ = input_model(image)  # Run the model on the image to define layer outputs

    # Create a model that outputs the convolutional layer and the predictions
    grad_model = tf.keras.models.Model(
        [input_model.inputs],
        [input_model.get_layer(layer_name).output, input_model.output]
    )

    # Record operations for automatic differentiation
    with tf.GradientTape() as tape:
        conv_outputs, predictions = grad_model(image)
        loss = predictions[:, cls]

    # Compute the gradients of the loss with respect to the conv layer output
    grads = tape.gradient(loss, conv_outputs)

    # Pool the gradients across the width and height dimensions (average pooling)
    pooled_grads = tf.reduce_mean(grads, axis=(0, 1, 2))

    # Multiply each feature map in the conv layer output by its corresponding pooled gradient
    conv_outputs = conv_outputs[0]
    heatmap = conv_outputs @ pooled_grads[..., tf.newaxis]
    heatmap = tf.squeeze(heatmap)

    # Apply ReLU and normalize the heatmap between 0 and 1
    heatmap = np.maximum(heatmap, 0) / (np.max(heatmap) + 1e-10)

    return heatmap

# Function to overlay heatmap on the image
def overlay_heatmap(heatmap, image, alpha=0.4, colormap=cv2.COLORMAP_VIRIDIS):
    # Resize heatmap to the size of the original image
    heatmap = cv2.resize(heatmap, (image.shape[1], image.shape[0]))

    # Convert the heatmap to 8-bit (0-255)
    heatmap = np.uint8(255 * heatmap)

    # Apply the colormap to the heatmap
    heatmap = cv2.applyColorMap(heatmap, colormap)

    # Superimpose the heatmap on the original image
    superimposed_img = cv2.addWeighted(heatmap, alpha, image, 1 - alpha, 0)

    return superimposed_img

# Test the Grad-CAM implementation on a single image
def run_grad_cam(model, test_set, layer_name):
    # Select a test image (ensure it is preprocessed as required by the model)
    test_image = test_set[0]  # Use the first image from the test set

    # Get the predicted class for the image
    predicted_class = np.argmax(model.predict(test_image))

    # Generate the Grad-CAM heatmap
    heatmap = grad_cam(model, test_image, predicted_class, layer_name)

    # Convert the image to a displayable format (uint8)
    image_for_overlay = np.uint8(255 * test_image[0])

    # Convert image from RGB to BGR format for OpenCV (if necessary)
    if image_for_overlay.shape[-1] == 3:
        image_for_overlay = cv2.cvtColor(image_for_overlay, cv2.COLOR_RGB2BGR)

    # Overlay the heatmap on the image
    superimposed_img = overlay_heatmap(heatmap, image_for_overlay)

    # Display the result using Matplotlib
    plt.figure(figsize=(10, 10))
    plt.imshow(cv2.cvtColor(superimposed_img, cv2.COLOR_BGR2RGB))  # Convert BGR to RGB for display
    plt.axis('off')  # Hide axis labels
    plt.title("Grad-CAM")
    plt.show()

# %%
def occlusion_sensitivity(model, image, label, patch_size=8):
    width, height, _ = image.shape
    heatmap = np.zeros((width, height))
    for i in range(0, width, patch_size):
        for j in range(0, height, patch_size):
            occluded_image = image.copy()
            occluded_image[i:i+patch_size, j:j+patch_size] = 0
            occluded_image = np.expand_dims(occluded_image, axis=0)
            prediction = model.predict(occluded_image)
            heatmap[i:i+patch_size, j:j+patch_size] = prediction[0][label]
    heatmap = (heatmap - np.min(heatmap)) / (np.max(heatmap) - np.min(heatmap))
    return heatmap

# Choose an image from the test set for explanation
test_image = next(test_set)[0][0] # Access the first image from the next batch using next()
test_label = np.argmax(model.predict(test_image[np.newaxis, ...]))
# Compute Occlusion Sensitivity
occlusion_heatmap = occlusion_sensitivity(model, test_image, test_label)
plt.imshow(occlusion_heatmap, cmap='viridis')
plt.title("Occlusion Sensitivity")
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# ...

# %%
import tensorflow as tf
import numpy as np
import cv2
import matplotlib.pyplot as plt

def compute_saliency_maps(model, images, labels):
    images = tf.convert_to_tensor(images)
    with tf.GradientTape() as tape:
        tape.watch(images)
        predictions = model(images)
        loss = tf.keras.losses.sparse_categorical_crossentropy(labels, predictions, from_logits=True) # Added missing argument from_logits=True
        grads = tape.gradient(loss, images)
    return tf.reduce_max(tf.abs(grads), axis=-1).numpy()

# Choose an image from the test set for explanation
test_image = test_set[0] # Assuming test_set is a list or tuple of images

# Select the first image from the batch
image = test_image[0]
# Display the first image from the batch
plt.imshow(image[0]) # Access the first image from the batch using index 0
plt.title("Original Image")
plt.show()
